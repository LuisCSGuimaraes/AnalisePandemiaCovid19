# %% [markdown]
# <img alt="Colaboratory logo" width="100%" src="https://raw.githubusercontent.com/LuisCSGuimaraes/Portfolio/main/Images/Banner.png">
#
#
# *Um projeto inspirado por:*
#
# <img alt="Colaboratory logo" width="10%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# **Data Science na Prática 2.0**
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
#
#
# ---

# %% [markdown]
# # Os números da pandemia - Panorama da COVID-19 no Brasil e no Mundo
#
# A Covid-19, doença causada pelo vírus SARS-CoV-2, teve seus primeiros casos apresentados na cidade de Wuhan, capital da província de Hubei, na China, no final do ano de 2019. A doença pode apresentar-se como uma infecção branda, podendo também desencadear pneumonia, insuficiência respiratória e até a morte.
#
# No dia 23 de janeiro de 2020, foi decretada quarentena na cidade de Wuhan, no entanto, a doença não ficou restrita àquela localidade e espalhou-se, primeiramente, pela China, em seguida, Ásia e, assim, para outros países. No dia 11 de março do mesmo ano, a Organização Mundial de Saúde (OMS) decretou estado de pandemia da Covid-19. Naquela data, já havia mais de 118 mil casos da doença registrados em mais de 100 países e 4.291 mortes. (Fonte: [Biologianet](https://www.biologianet.com/doencas/pandemia.htm))
#
# <center><img alt="Coronavirus" width="100%" src="https://raw.githubusercontent.com/LuisCSGuimaraes/AnalisePandemiaCovid19/main/Images/coronavirus.jpg"></center>
#
# No momento da realização desse estudo o mundo ainda passa pela pandemia, algumas vacinas já foram desenvolvidas e estão sendo aplicadas em diversos países, incluindo no Brasil, porém, não com a velocidade desejada. Pessoas continuam morrendo e infelizmente não sabemos quando tudo isso irá passar.
#
# A intenção desta análise é visualizar os números da pandemia e traçar um panorama da atual situação do Brasil e do mundo diante do vírus SARS-CoV-2.

# %% [markdown]
# # Índice
# * [Fonte e obtenção dos dados](#fonte_dados)
# * [Dicionário de variáveis](#dicionario)
# * [Análise inicial](#analise_inicial)
# * [Análise exploratória dos dados](#analise_dados)
#     - [Panorama mundial](#mundo)
#         - [Qual a situação da pandemia no mundo?](#situacao_mundo)
#         - [Comparação: 24/05/2020 com 24/05/2021 (mundo)](#comparacao_mundo)
#         - [Panorama da vacinação no mundo](#vacinacao_mundo)
#     - [Panorama brasileiro](#brasil)
#         - [Qual a situação da pandemia no Brasil?](#situacao_brasil)
#         - [Comparação: 24/05/2020 com 24/05/2021 (Brasil)](#comparacao_brasil)
#         - [Panorama da vacinação no Brasil](#vacinacao_brasil)
# * [Considerações finais](#consideracoes_finais)

# %% [markdown]
# # Fonte e obtenção dos dados <a name='fonte_dados'></a>
#
#
# Os dados utilizados neste notebook foram extraídos do [Github](https://github.com/owid/covid-19-data/tree/master/public/data) do portal [Our World in Data](https://ourworldindata.org/), que é um conceituada públicação digital especializada em expor pesquisas empíricas e dados analíticos sobre os mais diversos tópicos e assuntos de interesse mundial. Foi criada por Max Roser sob tutela da universidade de Oxford em 2011.
#
# Além de utilizar sua própria equipe de coleta de dados, o Our World in Data se valeu de informações coletadas por diversas outras instituições confiáveis ao redor do mundo, como o [Center for Systems Science and Engineering (CSSE) da Johns Hopkins University (JHU)](https://github.com/CSSEGISandData/COVID-19), por exemplo,  para compilar o dataset aqui utilizado. No Github oficial é possível encontrar todas as fontes e instituições utilizadas pelo Our World in Data para a compilação do dataset, link [aqui](https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-codebook.csv).
#
# É preciso de dizer que, apesar da confiabilidade da fonte de dados utilizada, não existe verdade absoluta. Isso se deve à infinidade de fonte de dados disponíveis e muitas vezes conflitantes a respeito da Covid-19. Por isso, esse estudo deve ser encarado apenas como informativo e não pode ser levado como tomador de decisão sob nenhuma circunstancia.
#
# Irei utilizar uma cópia do dataset do Our World in Data, extraída no dia 25/05/2021 e armazenada no meu próprio [Github](https://github.com/LuisCSGuimaraes), de modo a evitar a perda da fonte de dados caso o Github oficial seja fechado. [Aqui](https://raw.githubusercontent.com/LuisCSGuimaraes/AnalisePandemiaCovid19/main/RawData/owid-covid-data.csv) está o link.

# %%
#Instalando bibliotecas faltantes
#!pip install folium -q
#!pip install seaborn --upgrade

# %%
#Importando as bibliotecas necessárias
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import folium #Biblioteca para criação de gráficos
from branca.element import * #Biblioteca com recursos extras para mapas criados com a folium

#Lendo e armazenando o dataset em uma variável
DATA = 'https://raw.githubusercontent.com/LuisCSGuimaraes/AnalisePandemiaCovid19/main/RawData/owid-covid-data.csv'
df = pd.read_csv(DATA)

#Exibindo as primeiras linhas
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %% [markdown]
# # Dicionário de variáveis <a name='dicionario'></a>
#
# Para entender melhor o dataset que estamos trabalhando é necessário criar um dicionário de variáveis, dessa forma temos um lugar para consultar caso tenhamos alguma dúvida a respeito de algum dado. Por sorte, o Our World in Data já possui um dicionário de variáveis ([link](https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-codebook.csv))  pronto para ser utilizado.
#
# Realizei uma cópia desse dicionário, também no dia 25/05/2021, traduzi o seu conteúdo e importei para o meu Github para utilizar nesse notebook.
# O link está [aqui](https://raw.githubusercontent.com/LuisCSGuimaraes/AnalisePandemiaCovid19/main/RawData/dicionario_variaveis_covid19.csv).

# %%
#Importando o dicionário para a variável 'dicionario'.
dicionario = pd.read_csv('https://raw.githubusercontent.com/LuisCSGuimaraes/AnalisePandemiaCovid19/main/RawData/dicionario_variaveis_covid19.csv')

#Como a descrição de cada coluna é muito extensa, alterei o tamanho da visualização no pandas para conseguir acomodar tudo.
pd.options.display.max_colwidth = 350

#Exibindo o dicionário
dicionario
# Out:
#                                    coluna  \
# 0                                iso_code
# 1                               continent
# 2                                location
# 3                                    date
# 4                             total_cases
# 5                               new_cases
# 6                      new_cases_smoothed
# 7                            total_deaths
# 8                              new_deaths
# 9                     new_deaths_smoothed
# 10                total_cases_per_million
# 11                  new_cases_per_million
# 12         new_cases_smoothed_per_million
# 13               total_deaths_per_million
# 14                 new_deaths_per_million
# 15        new_deaths_smoothed_per_million
# 16                      reproduction_rate
# 17                           icu_patients
# 18               icu_patients_per_million
# 19                          hosp_patients
# 20              hosp_patients_per_million
# ...

# %%
#Retornando a visualização do pandas para o tamanho padrão
pd.options.display.max_colwidth = 50

# %% [markdown]
# # Análise inicial <a name='analise_inicial'></a>
#
# Com o dataset importado e o dicionário de variáveis criado podemos seguir para a análise inicial dos dados, onde verificaremos a estrutura básica do dataset, a existência de valores nulos e sua porcentagem em relação ao total.

# %%
#Imprimindo a estrutura básica do dataset, em formato de linhas(dados) e colunas(variáveis)
print("Estrutura do dataset: \n")
print("Quantidade de linhas: ",df.shape[0])
print("Quantidade de colunas: ",df.shape[1])
print("-----------------------")
# Out:
# Estrutura do dataset:
#
# Quantidade de linhas:  91026
# Quantidade de colunas:  59
# -----------------------

# %%
#Verificando os tipos e os valores não nulos de cada coluna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91026 entries, 0 to 91025
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               91026 non-null  object
#  1   continent                              86699 non-null  object
#  2   location                               91026 non-null  object
#  3   date                                   91026 non-null  object
#  4   total_cases                            88336 non-null  float64
#  5   new_cases                              88335 non-null  float64
#  6   new_cases_smoothed                     87328 non-null  float64
#  7   total_deaths                           78484 non-null  float64
#  8   new_deaths                             78642 non-null  float64
#  9   new_deaths_smoothed                    87328 non-null  float64
# ...

# %% [markdown]
# Percebemos que existem valores nulos no dataset e precisamos identificar a quantidade e a porcentagem em comparação ao total dos dados para, então, tentar analisar e entender o motivo desta ausência.
#
# Podemos perceber, também, que a coluna `date` está com o tipo `object`, precisamos alterar para `datetime`, de modo que possamos trabalhar de uma maneira melhor com seus valores.

# %%
#Alterando o tipo da coluna date.
df.date = pd.to_datetime(df.date)

# %%
#Verificando a quantidade absoluta e a porcentagem de valores nulos
null_abs = df.isnull().sum().sort_values(ascending=False)
null_perc = (((df.isnull().sum())/df.shape[0])*100).sort_values(ascending=False)

#Exibindo os resultados
print("---Valores nulos absolutos:---")
print(null_abs)
print("\n")
print("---Porcentagem de valores nulos:---")
print(null_perc)
# Out:
# ---Valores nulos absolutos:---
# weekly_icu_admissions                    90196
# weekly_icu_admissions_per_million        90196
# weekly_hosp_admissions_per_million       89580
# weekly_hosp_admissions                   89580
# people_fully_vaccinated                  82259
# people_fully_vaccinated_per_hundred      82259
# icu_patients                             81850
# icu_patients_per_million                 81850
# new_vaccinations                         80842
# people_vaccinated_per_hundred            79673
# people_vaccinated                        79673
# hosp_patients                            79611
# hosp_patients_per_million                79611
# total_vaccinations_per_hundred           78920
# total_vaccinations                       78920
# new_vaccinations_smoothed_per_million    70489
# new_vaccinations_smoothed                70489
# total_tests                              50153
# total_tests_per_thousand                 50153
# ...

# %% [markdown]
# Podemos perceber uma grande parcela de dados ausentes em algumas variáveis do dataset. Por exemplo, as variáveis `weekly_icu_admissions`, `weekly_icu_admissions_per_million`, `weekly_hosp_admissions ` e `weekly_hosp_admissions_per_million ` possuem acima de 98% dos seus dados ausentes. Porém, ao olhar com mais atenção, pode-se notar que a maior parte dos dados faltantes referem-se a: hospitalizações ou pacientes em unidades de tratamento intensivo (ICU, em inglês), testes para detecção de Covid-19 e vacinação.
#
# Dito isto, podemos fazer as seguintes análises a respeito dos dados ausentes no dataset:
#
# * **Dados referentes a hospitalização:** os dados coletados pelo Our World in Data vêm apenas dos Estados Unidos, do Reino Unido, do Canadá e de alguns países da União Europeia, como pode ser lido no tópico **Hospitalizations and intensive care unit (ICU) admissions**, [aqui](https://github.com/owid/covid-19-data/tree/master/public/data#the-data-you-find-here-and-our-data-sources)
#
# * **Dados de testes para COVID-19:** conforme dito no tópico **Testing for COVID-19**, [neste link](https://github.com/owid/covid-19-data/tree/master/public/data#the-data-you-find-here-and-our-data-sources), os dados são coletados pela equipe do Our World in Data através de relatórios oficiais, porém, muitos países não disponibilizam esses relatórios, além disso, os testes diferem de país para país e nem todos disponibilizam informações suficientes a respeito. Outra dificuldade é a diferente frequência na publicação dos dados. Mais informações a respeito podem ser encontradas [neste](https://ourworldindata.org/coronavirus-testing#our-checklist-for-covid-19-testing-data) e [neste](https://ourworldindata.org/coronavirus-testing#which-countries-do-we-have-testing-data-for) link.
#
# * **Dados sobre vacinação:** a vacinação contra a Covid-19 iniciou-se a pouco tempo, sendo o [Reino Unido o primeiro país do Ocidente a iniciar a vacinação](https://www.cnnbrasil.com.br/saude/2020/12/24/quais-os-paises-que-ja-comecaram-a-vacinacao-contra-a-covid-19), em dezembro de 2020.
#
# Realizada essa análise inicial e tendo uma compreensão da estrutura do dataset e de seus dados, podemos passar para a análise exploratória em busca de mais informações a respeito da pandemia.

# %% [markdown]
# # Análise Exploratória dos Dados <a name='analise_dados'></a>
#
# A Covid-19 atingiu diversos países e ainda é responsável por diversas mortes ao redor do globo. Para tentar entender a atual situação da doença, a análise dos dados será divida entre o panorama mundial e o panorama brasileiro em relação à pandemia.
#
# Começaremos com o panorama mundial.

# %% [markdown]
# ## Panorama mundial <a name='mundo'></a>

# %% [markdown]
# ### Qual a situação da pandemia no mundo? <a name='situacao_mundo'></a>
#
# O coronavírus se espalhou pelo mundo com grande velocidade, fazendo os países a adotarem medidas protetivas diferentes um dos outros na esperança de conter o avanço da doença. Algumas medidas foram mais eficazes do que outras, o que fez com que alguns locais apresentassem números maiores de novos casos e de mortes pela Covid-19.
#
# Vejamos, primeiramente, um gráfico representando o avanço de novos casos da doença pelo mundo durante todo o período disponível no dataset.

# %%
#Mudando o estilo do Seaborn
sns.set_theme(style='whitegrid')

# %%
#Criando dataframe para o mundo
df_mundo = df.loc[df.location == 'World']

#Criando a figure
figure, ax = plt.subplots(figsize=(15,6), ncols=2)

#Configurando o estilo do seaborn
sns.despine(top=True, right=True)
sns.set_context("paper", rc={"font.size":8,"axes.titlesize":12}) 

#Plotando o Gráfico I
sns.lineplot(x='date', y='new_cases_smoothed', ax=ax[0], data=df_mundo, color='red', linewidth=.8 )
ax[0].set_ylabel("Novos casos suavizados em 7 dias")
ax[0].set_xlabel("Data")
ax[0].set_title("Gráfico I - Novos casos de COVID-19 (7 dias) no mundo")

#Plotando o Gráfico II
sns.lineplot(x='date', y='new_deaths_smoothed', ax=ax[1], data=df_mundo, color='orange', linewidth=.8 )
ax[1].set_ylabel("Novas mortes suavizadas em 7 dias")
ax[1].set_xlabel("Data")
ax[1].set_title("Gráfico II - Novas mortes devido à COVID-19 (7 dias) no mundo")

#Exibindo os gráficos
plt.tight_layout()

# %% [markdown]
# Podemos notar, com bastante clareza, o aumento nos números de casos de Covid-19 desde o início da pandemia, com poucos pontos de queda. O que é seguido de perto pelos números de mortes causadas pela doença, com um expressivo e rápido aumento no início de 2020, quando tínhamos poucas, ou nenhuma, informação a respeito do vírus.
#
# Por outro lado, percebemos uma forte queda nos números de novos casos e de mortes nos primeiros meses de 2021. Uma queda bastante expressiva, porém que veio seguida de um novo rápido aumento.
#
# Vamos tentar explorar e analisar essa forte variação de novos casos e mortes nos primeiros meses de 2021, primeiramente separando a análise por continente.

# %%
#Mudando o estilo do Seaborn
sns.set_theme(style='white')

# %%
#Criando a figure
figure, ax = plt.subplots(figsize=(18,6), ncols=2)

#Configurando o estilo do seaborn
sns.despine(top=True, right=True)
sns.set_context("paper", rc={"font.size":8,"axes.titlesize":12}) 


#Plotando o Gráfico III
sns.lineplot(x='date', y='new_cases_smoothed', ax=ax[0], data=df, hue='continent', palette='tab10', linewidth=1.5, ci=None)

ax[0].set_ylabel("Novos casos suavizados em 7 dias")
ax[0].set_xlabel("Data")
ax[0].set_title("Gráfico III - Novos casos de COVID-19 (7 dias) - Continentes")
ax[0].legend(fontsize=12, loc='best')

#Plotando o Gráfico IV
sns.lineplot(x='date', y='new_deaths_smoothed', ax=ax[1], data=df, hue='continent', palette='tab10_r', linewidth=1.5, ci=None)

ax[1].set_ylabel("Novas mortes suavizados em 7 dias")
ax[1].set_xlabel("Data")
ax[1].set_title("Gráfico IV - Novas mortes devido à COVID-19 (7 dias) - Continentes")
ax[1].legend(fontsize=12, loc='best')

#Exibindo os gráficos
plt.tight_layout()

# %% [markdown]
# Podemos perceber algo bastante interessante: o período em que o gráfico da análise mundial (Gráficos I e II) apresenta queda é igual ao período em que a América do Norte e o continente europeu também apresentam queda no gráfico da análise por continentes (Gráficos III e IV).
#
# Vamos plotar os quatro gráficos juntos para uma visualização melhor.

# %%
#Criando a figure
figure, ax = plt.subplots(figsize=(14,8), nrows=2 ,ncols=2)

#Plotando o Gráfico I
sns.lineplot(x='date', y='new_cases_smoothed', ax=ax[0,0], data=df_mundo, color='red', linewidth=.8 )
ax[0,0].set_ylabel("Novos casos suavizados em 7 dias")
ax[0,0].set_xlabel("Data")
ax[0,0].set_title("Gráfico I - Novos casos de COVID-19 (7 dias) no mundo")

#Plotando o Gráfico III
sns.lineplot(x='date', y='new_cases_smoothed', ax=ax[0,1], data=df, hue='continent', palette='tab10', linewidth=1.5, ci=None)

ax[0,1].set_ylabel("Novos casos suavizados em 7 dias")
ax[0,1].set_xlabel("Data")
ax[0,1].set_title("Gráfico III - Novos casos de COVID-19 (7 dias) - Continentes")
ax[0,1].legend(fontsize=12, loc='best')

#Plotando o Gráfico II
sns.lineplot(x='date', y='new_deaths_smoothed', ax=ax[1,0], data=df_mundo, color='orange', linewidth=.8 )
ax[1,0].set_ylabel("Novas mortes suavizadas em 7 dias")
ax[1,0].set_xlabel("Data")
ax[1,0].set_title("Gráfico II - Novas mortes devido à COVID-19 (7 dias) no mundo")

#Plotando o Gráfico IV
sns.lineplot(x='date', y='new_deaths_smoothed', ax=ax[1,1], data=df, hue='continent', palette='tab10_r', linewidth=1.5, ci=None)

ax[1,1].set_ylabel("Novas mortes suavizados em 7 dias")
ax[1,1].set_xlabel("Data")
ax[1,1].set_title("Gráfico IV - Novas mortes devido à COVID-19 (7 dias) - Continentes")
ax[1,1].legend(fontsize=12, loc='best')

#Exibindo os gráficos
plt.tight_layout()

# %% [markdown]
# Ao compararmos os 4 gráficos lado a lado podemos perceber que o período em que a América do Norte e a Europa apresentam queda em seus números de novos casos e de óbitos pela Covid-19 coincide com a diminuição desses mesmos números nos gráficos referentes ao mundo, o que pode explicar a queda global no início de 2021, visto que estas localizações representavam a maior parte dos casos no mundo. Uma matéria publicada no site El País retrata bem isto, como pode ser lido [aqui](https://brasil.elpais.com/internacional/2021-02-20/mundo-consolida-o-primeiro-retrocesso-do-coronavirus-desde-o-inicio-da-pandemia.html).
#
# Por outro lado, o repentino aumento que vemos logo em seguida coincide com os aumentos dos números de novos casos e de óbitos na América do Sul, puxados pelo Brasil (como [noticiado](https://forbes.com.br/colunas/2020/04/oms-aumento-nos-casos-de-coronavirus-na-america-do-sul-e-preocupante/) pela Forbes),  e no continente asiático, principalmente na índia (como pode ser lido [nesta matéria](https://www.bbc.com/portuguese/internacional-56900334) da BBC), o que pode explicar o aumento da curva referente a esses números em escala global.
#
# A queda de novos casos, vista no final do Gráfico I, pode ser explicada pela queda desse mesmo número no continente asiático, visto no final do Gráfico III. Percebemos, ainda, que a América do Sul é a região com a maior quantidade de novos casos ao final do período analisado, como pode ser visto também no Gráfico III.
#
# Vamos agora retirar algumas informações estatísticas dos dados que estamos analisando.

# %%
#Passando os valores para listas para serem exibidos
df_stats_obito = df[["location","total_deaths"]].loc[df.continent.notnull()].sort_values(by="total_deaths", ascending=False).values.tolist()
df_stats_casos = df[["location","total_cases"]].loc[df.continent.notnull()].sort_values(by="total_cases", ascending=False).values.tolist()
df_stats_obito_million = df[["location","total_deaths_per_million"]].loc[df.location == "World"].sort_values(by="total_deaths_per_million", ascending=False).values.tolist()
df_stats_casos_million = df[["location","total_cases_per_million"]].loc[df.location == "World"].sort_values(by="total_cases_per_million", ascending=False).values.tolist()
populacao2020 = df.population.loc[(df.date == '2020-12-31') & (df.location =='World')].sort_values(ascending=False).values.tolist()
mortalidade = (df.total_deaths.max() * 100000/populacao2020[0])
letalidade = (df.total_deaths.max() * 100)/df.total_cases.max()

#Exibindo os valores armazenados

print("\n---------------ESTATÍSTICAS DA COVID-19 ATÉ O ÚLTIMO DIA ANALISADO - 25/05/2021, COM DADOS DO DIA 24/05/2021--------------")
print("--------------------------------------------------------------------------------------------------------------------------\n")
print("* Casos totais de Covid-19 no mundo: {:,.0f}".format(df.total_cases.max()),".")
print("* Quantidade de óbitos devidos à Covid-19: {:,.0f}".format(df.total_deaths.max()),".")
print("* O país com a maior quantidade de casos é",df_stats_casos[0][0], "com {:,.0f}".format(df_stats_casos[0][1]), "casos.")
print("* O país com a maior quantidade de óbitos é",df_stats_obito[0][0], "com {:,.0f}".format(df_stats_obito[0][1]), "óbitos.")
print("* O mundo apresenta, até a data deste estudo, {:,.0f}".format(df_stats_obito_million[0][1]), "óbitos por milhão de infectados.")
print("* O mundo apresenta, até a data deste estudo, {:,.0f}".format(df_stats_casos_million[0][1]), "novos casos de Covid-19 por milhão de habitantes.")
print("* A taxa de letalidade mundial da Covid-19, até a data deste estudo, é de {:.2f}%".format(letalidade),".")
print("* A taxa de mortalidade da Covid-19, considerando a população mundial em 2020, é de {:.0f}".format(mortalidade),"a cada 100.000 habitantes.\n")
print("==========================================================================================================================")
# Out:
# ---------------ESTATÍSTICAS DA COVID-19 ATÉ O ÚLTIMO DIA ANALISADO - 25/05/2021, COM DADOS DO DIA 24/05/2021--------------
# --------------------------------------------------------------------------------------------------------------------------
#
# * Casos totais de Covid-19 no mundo: 167,316,360 .
# * Quantidade de óbitos devidos à Covid-19: 3,473,036 .
# * O país com a maior quantidade de casos é United States com 33,143,662 casos.
# * O país com a maior quantidade de óbitos é United States com 590,320 óbitos.
# * O mundo apresenta, até a data deste estudo, 446 óbitos por milhão de infectados.
# * O mundo apresenta, até a data deste estudo, 21,465 novos casos de Covid-19 por milhão de habitantes.
# * A taxa de letalidade mundial da Covid-19, até a data deste estudo, é de 2.08% .
# * A taxa de mortalidade da Covid-19, considerando a população mundial em 2020, é de 45 a cada 100.000 habitantes.
#
# ...

# %% [markdown]
# Isso nos dá um retrato da pandemia pelo mundo. Sabemos, porém, que o vírus atingiu os países de maneiras diferentes, com a população de uns sofrendo mais do que a população de outros.
#
# Vejamos, através de alguns gráficos, o ranking dos países mais afetados pela pandemia durante o período analisado.

# %%
#Configurando o estilo das spines
rc_params_bar = {'axes.spines.top':False, 
                  'axes.spines.right': False, 
                  'axes.spines.bottom': False,
                  'axes.titlesize':11}  

#Definindo os dados a serem plotados
top5_total_deaths = df.loc[( df.date == '2021-05-24') & (df.continent.notnull())].sort_values(by="total_deaths", ascending=False)[0:5]
top5_total_cases = df.loc[(df.date == '2021-05-24') & (df.continent.notnull())].sort_values(by="total_cases", ascending=False)[0:5]

#Aplicando o estilo
with plt.rc_context(rc_params_bar): 
  
  #Criando a figura
  fig, ax = plt.subplots(figsize=(15,6), ncols=2)
  
  #Plotando o Gráfico V
  tc = sns.barplot(x='location', y="total_cases", ax = ax[0], data=top5_total_cases, palette='RdPu_r')
  ax[0].ticklabel_format(style='plain', axis='y')
  ax[0].set(ylim=(0,35000000))
  ax[0].set_ylabel("Quantidade de casos")
  ax[0].set_xlabel("Países")
  ax[0].set_title("Gráfico V - Os 5 países com o maior número de casos (em números absolutos)")
  for p in tc.patches:
    tc.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')

  #Plotando o Gráfico VI
  td = sns.barplot(x='location', y="total_deaths", ax = ax[1], data=top5_total_deaths, palette='PuRd_r')
  ax[1].set_ylabel("Quantidade de óbitos")
  ax[1].set_xlabel("Países")
  ax[1].set_title("Gráfico VI - Os 5 países com o maior número de óbitos (em números absolutos)")
  for p in td.patches:
    td.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')

#Exibindo
plt.tight_layout()

# %% [markdown]
# Ao analisarmos os números absolutos de óbitos e de casos de Covid-19 ao redor do mundo percebemos que três nomes são repetidos em ambos os gráficos: Estados Unidos, Índia e Brasil. Precisamos ter cuidado com esses números devido à demografia de cada país, países muito populosos tenderão a ter um número absoluto maior de casos e de óbitos quando comparados a países menos populosos.
#
# Logo, devemos considerar a densidade populacional de cada localidade ao plotar os gráficos. Por sorte, nosso dataset possui variáveis que indicam a quantidade de casos e de óbitos por milhão de habitantes e iremos utiliza-las para plotar os próximos gráficos.

# %%
#Configurando o estilo das spines
rc_params_bar = {'axes.spines.top':False, 
                  'axes.spines.right': False, 
                  'axes.spines.bottom': False,
                  'axes.titlesize':11}  

#Definindo os dados a serem plotados
top5_total_deaths_million = df.loc[( df.date == '2021-05-24') & (df.continent.notnull())].sort_values(by="total_deaths_per_million", ascending=False)[0:5]
top5_total_cases_million = df.loc[(df.date == '2021-05-24') & (df.continent.notnull())].sort_values(by="total_cases_per_million", ascending=False)[0:5]

#Aplicando o estilo
with plt.rc_context(rc_params_bar): 
  
  #Criando a figura
  fig, ax = plt.subplots(figsize=(15,6), ncols=2)

  #Plotando o Gráfico VII
  tcm = sns.barplot(x='location', y="total_cases_per_million", ax = ax[0], data=top5_total_cases_million, palette='OrRd_r')
  ax[0].ticklabel_format(style='plain', axis='y')
  ax[0].set_ylabel("Quantidade de casos")
  ax[0].set_xlabel("Países")
  ax[0].set_title("Gráfico VII - Os 5 países com o maior número de casos (por milhão de habitantes)")
  for p in tcm.patches:
    tcm.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')

  #Plotando o Gráfico VIII
  tdm = sns.barplot(x='location', y="total_deaths_per_million", ax = ax[1], data=top5_total_deaths_million, palette='Oranges_r')
  ax[1].set_ylabel("Quantidade de óbitos")
  ax[1].set_xlabel("Países")
  ax[1].set_title("Gráfico VIII - Os 5 países com o maior número de óbitos (por milhão de habitantes)")
  for p in tdm.patches:
    tdm.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')

#Exibindo
plt.tight_layout()

# %% [markdown]
# Utilizar as variáveis `total_deaths_per_million` e `total_cases_per_million` retirou o viés populacional do nosso plot e nos deu uma visão mais realista a respeito dos números analisados.
#
# Andorra, por exemplo, é um país com cerca de 83 mil habitantes [(Fonte)](https://pt.wikipedia.org/wiki/Demografia_de_Andorra) e que possuía 13.569 casos de Covid-19 no dia 24/05/2021. Apesar de os números parecerem pequenos em comparação a outros países, isso no dá uma proporção de 175.616 casos por milhão de habitantes.
#
# Vejamos os números de óbitos e casos por milhão de habitantes através do plot em um mapa-múndi.

# %%
##### Pré-processando os dados necessários para criar os mapas #####

#Criando o dataframe para o mapa
df_mapa = df.loc[df.date == '2021-05-24']
df_mapa = df_mapa.loc[df_mapa.continent.notnull()]

#Editando o nome dos paises na coluna location de modo a serem iguais ao arquivo json utilizado na biblioteca folium
df_mapa.location = df_mapa.location.replace(['United States'], "United States of America")
df_mapa.location = df_mapa.location.replace(['Tanzania'], "United Republic of Tanzania")
df_mapa.location = df_mapa.location.replace(['Democratic Republic of Congo'], "Democratic Republic of the Congo")
df_mapa.location = df_mapa.location.replace(['Guinea-Bissau'], "Guinea Bissau")
df_mapa.location = df_mapa.location.replace(["Cote d'Ivoire"], "Ivory Coast")
df_mapa.location = df_mapa.location.replace(['Congo'], "Republic of the Congo")
df_mapa.location = df_mapa.location.replace(['Serbia'], "Republic of Serbia")
df_mapa.location = df_mapa.location.replace(['Czechia'], "Czech Republic")
df_mapa.location = df_mapa.location.replace(['North Macedonia'], "Macedonia")

#URL do arquivo json utilizado pela biblioteca folium
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
world = f'{url}/world-countries.json'

# %%
##### Criando o Mapa I #####

#Criando a figura para comportar o mapa
fig_casos=Figure(width='90%',)
fig_casos.header.add_child(Element("<style>body {overflow-y: hidden;}</style>"))
fig_casos.html.add_child(Element("<h3 align='center' style='font-size:20px'>Mapa da quantidade total de casos de Covid-19 no mundo (Por milhão de habitantes)<b></b></h3>"))

#Configurando o estilo do mapa
mapa_casos = folium.Map(location=[0,0],
               zoom_start=2,               
               max_zoom=6,
               min_zoom=2,
               tiles='https://api.mapbox.com/styles/v1/luisguimaraes/ckp7hro3q0pzj18qe3k56b9fj/tiles/256/{z}/{x}/{y}@2x?access_token=pk.eyJ1IjoibHVpc2d1aW1hcmFlcyIsImEiOiJja3A3aGltamIwMDlyMnhtczV6NDVsdzQwIn0.qb6NR-BDFNkj6R2M8X35yA', 
               attr="<a href=https://www.mapbox.com/>Mapbox</a>")

#Adicionando o mapa à figura
fig_casos.add_child(mapa_casos)

#Configurando o choropleth
folium.Choropleth(
    geo_data=world,
    name='choropleth COVID-19',
    data=df_mapa,
    columns=['location', 'total_cases_per_million'],
    key_on='feature.properties.name',
    fill_color='YlOrBr',
    fill_opacity=0.7,
    line_opacity=0.1,
    nan_fill_color='white',
    legend_name='Quantidade de casos'
).add_to(mapa_casos)

#Exibindo o mapa criado
mapa_casos
# Out:
# <div style="width:90%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cstyle%3Ebody%20%7Boverflow-y%3A%20hidden%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3B
# ...

# %%
##### Criando o Mapa II #####

#Criando a figura para comportar o mapa
fig_obitos=Figure(width='90%',)
fig_obitos.header.add_child(Element("<style>body {overflow-y: hidden;}</style>"))
fig_obitos.html.add_child(Element("<h3 align='center' style='font-size:20px'>Mapa de óbitos devido à Covid-19 no mundo (por milhão de habitantes)<b></b></h3>"))

#Configurando o estilo do mapa
mapa_obitos = folium.Map(location=[0,0],
               zoom_start=2,               
               max_zoom=6,
               min_zoom=2,
               tiles='https://api.mapbox.com/styles/v1/luisguimaraes/ckp7hro3q0pzj18qe3k56b9fj/tiles/256/{z}/{x}/{y}@2x?access_token=pk.eyJ1IjoibHVpc2d1aW1hcmFlcyIsImEiOiJja3A3aGltamIwMDlyMnhtczV6NDVsdzQwIn0.qb6NR-BDFNkj6R2M8X35yA', 
               attr="<a href=https://www.mapbox.com/>Mapbox</a>")

#Adicionando o mapa à figura
fig_obitos.add_child(mapa_obitos)

#Configurando o choropleth
folium.Choropleth(
    geo_data=world,
    name='choropleth COVID-19',
    data=df_mapa,
    columns=['location', 'total_deaths_per_million'],
    key_on='feature.properties.name',
    fill_color='OrRd',
    fill_opacity=0.7,
    line_opacity=0.1,
    nan_fill_color='white',
    legend_name='Número de óbitos'
).add_to(mapa_obitos)

#Exibindo o mapa criado
mapa_obitos
# Out:
# <div style="width:90%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cstyle%3Ebody%20%7Boverflow-y%3A%20hidden%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3B
# ...

# %% [markdown]
# ### Comparação entre 24/05/2020 e 24/05/2021  <a name='comparacao_mundo'></a>
#
#
# Até agora vimos a evolução da pandemia de uma maneira geral, desde a identificação do novo vírus e do início da coleta dos dados, até a data de 24 de maio de 2021.
# Agora realizarei uma comparação desta mesma data em comparação ao ano de 2020, na tentativa de avaliar os números quando confrontamos diretamente dois meses no intervalo de um ano. Para isso utilizarei as mesmas variáveis `total_deaths_per_million` e `total_cases_per_million` de modo a evitar um viés devido à diferença populacional de cada país, assim como fiz anteriormente.
#
# Primeiramente, vejamos quais eram os países com o maior número de casos e de óbitos em 24 de maio de 2020.

# %%
#Definindo os dados a serem plotados
df_dm_maio_2020 = df.loc[(df.date == '2020-05-24') & (df.continent.notnull())].sort_values(by='total_deaths_per_million', ascending = False)[0:5]
df_cm_maio_2020 = df.loc[(df.date == '2020-05-24') & (df.continent.notnull())].sort_values(by='total_cases_per_million', ascending = False)[0:5]


#Aplicando o estilo
with plt.rc_context(rc_params_bar): 
  
  #Criando a figura
  fig, ax = plt.subplots(figsize=(15,6), ncols=2)

  #Plotando o Gráfico VII
  cm2020 = sns.barplot(x='location', y="total_cases_per_million", ax = ax[0], data=df_cm_maio_2020 , palette='PuRd_r')
  ax[0].ticklabel_format(style='plain', axis='y')
  ax[0].set_ylabel("Quantidade de casos")
  ax[0].set_xlabel("Países")
  ax[0].set_title("Gráfico IX - Os 5 países com o maior número de casos (por milhão de habitantes) - 24/05/2020")
  for p in cm2020.patches:
    cm2020.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0,4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')

  #Plotando o Gráfico VIII
  dm2020 = sns.barplot(x='location', y="total_deaths_per_million", ax = ax[1], data=df_dm_maio_2020, palette='Purples_r')
  ax[1].set_ylabel("Quantidade de óbitos")
  ax[1].set_xlabel("Países")
  ax[1].set_title("Gráfico X - Os 5 países com o maior número de óbitos (por milhão de habitantes) - 24/05/2020")
  for p in dm2020.patches:
    dm2020.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')

#Exibindo
plt.tight_layout()

# %% [markdown]
# Percebemos que alguns países que aparecem no top 5 de 2021 já apareciam em 2020. San Marino, que aparece em quarto lugar em 2021, já aparecia em 2020 ocupando o primeiro lugar de casos e mortos por milhão, por exemplo.
#
# Vamos plotar uma comparação lado a lado de cada país no intuito de entender se houve uma melhora ou piora nos números no decorrer de um ano.

# %%
####Criando um novo dataframe com os países que em 2020 estavam no top 5 com os dados de 2021####

#Dataframe para o comparativo de casos
df_comparativo_cases = df.loc[(df.date == '2021-05-24') & (df.location == 'San Marino')].sort_values(by="total_cases_per_million", ascending=False)
df_comparativo_cases = pd.concat([df_comparativo_cases, df.loc[(df.date == '2021-05-24') & (df.location == 'Qatar')].sort_values(by="total_cases_per_million", ascending=False)], ignore_index=True)
df_comparativo_cases = pd.concat([df_comparativo_cases, df.loc[(df.date == '2021-05-24') & (df.location == 'Vatican')].sort_values(by="total_cases_per_million", ascending=False)], ignore_index=True)
df_comparativo_cases = pd.concat([df_comparativo_cases, df.loc[(df.date == '2021-05-24') & (df.location == 'Andorra')].sort_values(by="total_cases_per_million", ascending=False)], ignore_index=True)
df_comparativo_cases = pd.concat([df_comparativo_cases, df.loc[(df.date == '2021-05-24') & (df.location == 'Luxembourg')].sort_values(by="total_cases_per_million", ascending=False)], ignore_index=True)

#Dataframe para o comparativo de óbitos
df_comparativo_deaths = df.loc[(df.date == '2021-05-24') & (df.location == 'San Marino')].sort_values(by="total_deaths_per_million", ascending=False)
df_comparativo_deaths = pd.concat([df_comparativo_deaths, df.loc[(df.date == '2021-05-24') & (df.location == 'Belgium')].sort_values(by="total_deaths_per_million", ascending=False)], ignore_index=True)
df_comparativo_deaths = pd.concat([df_comparativo_deaths, df.loc[(df.date == '2021-05-24') & (df.location == 'Andorra')].sort_values(by="total_deaths_per_million", ascending=False)], ignore_index=True)
df_comparativo_deaths = pd.concat([df_comparativo_deaths, df.loc[(df.date == '2021-05-24') & (df.location == 'Spain')].sort_values(by="total_deaths_per_million", ascending=False)], ignore_index=True)
df_comparativo_deaths = pd.concat([df_comparativo_deaths, df.loc[(df.date == '2021-05-24') & (df.location == 'Italy')].sort_values(by="total_deaths_per_million", ascending=False)], ignore_index=True)

# %%
####Configurando o plot do gráfico XI - comparativo de casos#####

#Concatenando os dataframes de 2020 e 2021
comparativo_cases = pd.concat([df_cm_maio_2020, df_comparativo_cases], ignore_index=True)

#Criando a coluna Ano para melhor exibição
comparativo_cases['Ano'] = comparativo_cases.date.dt.year

#Exibindo o gráfico XI - comparativo dos países que estavam em top 5 em 2020 com os dados de 2021 para verificar os números
cc = sns.catplot(x='Ano', y='total_cases_per_million', col='location', data=comparativo_cases, kind='bar',  ci=None, aspect=.5, palette = 'Reds')
(cc.set_axis_labels("", "Total de casos (por milhão)")
  .set_titles("{col_name}")) 
cc.fig.subplots_adjust(top=0.8)
cc.fig.suptitle('Gráfico XI - Casos por milhão - Comparativo 24/05/2020 - 24/05/2021', fontsize=15)  


#Exibindo os números acima de cada barra
ax = cc.facet_axis(0,0)

for p in ax.patches:
    ax.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')

ax = cc.facet_axis(0,1)

for p in ax.patches:
    ax.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')


ax = cc.facet_axis(0,2)

for p in ax.patches:
    ax.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')


ax = cc.facet_axis(0,3)

for p in ax.patches:
    ax.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')

ax = cc.facet_axis(0,4)

for p in ax.patches:
    ax.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')



####Configurando o plot do gráfico XII - comparativo de óbitos#####                   

#Concatenando os dataframes de 2020 e 2021
comparativo_deaths = pd.concat([df_dm_maio_2020, df_comparativo_deaths], ignore_index=True)

#Criando a coluna Ano para melhor exibição
comparativo_deaths['Ano'] = comparativo_deaths.date.dt.year

#Exibindo o gráfico XI - comparativo dos países que estavam em top 5 em 2020 com os dados de 2021 para verificar os números
cd = sns.catplot(x='Ano', y='total_deaths_per_million', col='location', data=comparativo_deaths, kind='bar',  ci=None, aspect=.5, palette = 'YlOrRd')
(cd.set_axis_labels("", "Total de óbitos (por milhão)")
  .set_titles("{col_name}"))
cd.fig.subplots_adjust(top=0.8)
cd.fig.suptitle('Gráfico XII - Óbitos por milhão - Comparativo 24/05/2020 - 24/05/2021', fontsize=15)  


#Exibindo os números acima de cada barra
ax2 = cd.facet_axis(0,0)

for p in ax2.patches:
    ax2.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')


ax2 = cd.facet_axis(0,1)

for p in ax2.patches:
    ax2.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')


ax2 = cd.facet_axis(0,2)

for p in ax2.patches:
    ax2.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')


ax2 = cd.facet_axis(0,3)

for p in ax2.patches:
    ax2.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')

ax2 = cd.facet_axis(0,4)

for p in ax2.patches:
    ax2.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')                   


#exibindo os gráficos
plt.show()

# %%
#Cálculo do percentual de aumento de casos dos países do top 5 de 2020
pct_cases_sanmarino = (comparativo_cases.total_cases_per_million.loc[(comparativo_cases.location == "San Marino") & (comparativo_cases.Ano == 2021)]).values.tolist()[0]/(comparativo_cases.total_cases_per_million.loc[(comparativo_cases.location == "San Marino") & (comparativo_cases.Ano == 2020)]).values.tolist()[0] * 100 

pct_cases_qatar = (comparativo_cases.total_cases_per_million.loc[(comparativo_cases.location == "Qatar") & (comparativo_cases.Ano == 2021)]).values.tolist()[0]/(comparativo_cases.total_cases_per_million.loc[(comparativo_cases.location == "Qatar") & (comparativo_cases.Ano == 2020)]).values.tolist()[0] * 100 

pct_cases_vatican = (comparativo_cases.total_cases_per_million.loc[(comparativo_cases.location == "Vatican") & (comparativo_cases.Ano == 2021)]).values.tolist()[0]/(comparativo_cases.total_cases_per_million.loc[(comparativo_cases.location == "Vatican") & (comparativo_cases.Ano == 2020)]).values.tolist()[0] * 100 

pct_cases_andorra = (comparativo_cases.total_cases_per_million.loc[(comparativo_cases.location == "Andorra") & (comparativo_cases.Ano == 2021)]).values.tolist()[0]/(comparativo_cases.total_cases_per_million.loc[(comparativo_cases.location == "Andorra") & (comparativo_cases.Ano == 2020)]).values.tolist()[0] * 100 

pct_cases_luxembourg = (comparativo_cases.total_cases_per_million.loc[(comparativo_cases.location == "Luxembourg") & (comparativo_cases.Ano == 2021)]).values.tolist()[0]/(comparativo_cases.total_cases_per_million.loc[(comparativo_cases.location == "Luxembourg") & (comparativo_cases.Ano == 2020)]).values.tolist()[0] * 100 



#Cálculo do percentual de aumento de óbito dos países do top 5 de 2020
pct_death_sanmarino = (comparativo_deaths.total_deaths_per_million.loc[(comparativo_deaths.location == "San Marino") & (comparativo_deaths.Ano == 2021)]).values.tolist()[0]/(comparativo_deaths.total_deaths_per_million.loc[(comparativo_deaths.location == "San Marino") & (comparativo_deaths.Ano == 2020)]).values.tolist()[0] * 100 

pct_death_belgium =(comparativo_deaths.total_deaths_per_million.loc[(comparativo_deaths.location == "Belgium") & (comparativo_deaths.Ano == 2021)]).values.tolist()[0]/(comparativo_deaths.total_deaths_per_million.loc[(comparativo_deaths.location == "Belgium") & (comparativo_deaths.Ano == 2020)]).values.tolist()[0] * 100 

pct_death_andorra = (comparativo_deaths.total_deaths_per_million.loc[(comparativo_deaths.location == "Andorra") & (comparativo_deaths.Ano == 2021)]).values.tolist()[0]/(comparativo_deaths.total_deaths_per_million.loc[(comparativo_deaths.location == "Andorra") & (comparativo_deaths.Ano == 2020)]).values.tolist()[0] * 100 

pct_death_spain = (comparativo_deaths.total_deaths_per_million.loc[(comparativo_deaths.location == "Spain") & (comparativo_deaths.Ano == 2021)]).values.tolist()[0]/(comparativo_deaths.total_deaths_per_million.loc[(comparativo_deaths.location == "Spain") & (comparativo_deaths.Ano == 2020)]).values.tolist()[0] * 100 

pct_death_italy =(comparativo_deaths.total_deaths_per_million.loc[(comparativo_deaths.location == "Italy") & (comparativo_deaths.Ano == 2021)]).values.tolist()[0]/(comparativo_deaths.total_deaths_per_million.loc[(comparativo_deaths.location == "Italy") & (comparativo_deaths.Ano == 2020)]).values.tolist()[0] * 100 

#Exibindo o percentual de aumento de casos ao comparar as datas no período de um ano
print("\nAumento percentual nos casos de Covid-19 (por milhão): Países no top 5 de 2020 - Comparação entre 24/05/2020 e 24/05/2021 (período de um ano)")
print("---------------------------------------------------------------------------------------------------------------------------------------------")
print("San Marino apresentou um aumento de \033[1m{:.2f}% \033[0m".format(pct_cases_sanmarino, ), "nos números de casos.")
print("Catar apresentou um aumento de \033[1m{:.2f}%\033[0m".format(pct_cases_qatar), "nos números de casos.")
print("Vaticano apresentou um aumento de \033[1m{:.2f}%\033[0m".format(pct_cases_vatican), "nos números de casos.")
print("Andorra apresentou um aumento de \033[1m{:.2f}%\033[0m".format(pct_cases_andorra), "nos números de casos.")
print("Luxemburgo apresentou um aumento de \033[1m{:.2f}%\033[0m".format(pct_cases_luxembourg), "nos números de casos.\n\n")

#Exibindo o percentual de aumento de óbitos ao comparar as datas no período de um ano
print("Aumento percentual no nº de óbitos devido à Covid-19 (por milhão): Países no top 5 de 2020 - Comparação entre 24/05/2020 e 24/05/2021 (período de um ano)")
print("---------------------------------------------------------------------------------------------------------------------------------------------------------")
print("San Marino apresentou um aumento de \033[1m{:.2f}% \033[0m".format(pct_death_sanmarino, ), "nos números de óbitos devido à Covid-19.")
print("Bélgica apresentou um aumento de \033[1m{:.2f}%\033[0m".format(pct_death_belgium), "nos números óbitos devido à Covid-19.")
print("Andorra apresentou um aumento de \033[1m{:.2f}%\033[0m".format(pct_death_andorra), "nos números óbitos devido à Covid-19.")
print("Espanha apresentou um aumento de \033[1m{:.2f}%\033[0m".format(pct_death_spain), "nos números óbitos devido à Covid-19.")
print("Itália apresentou um aumento de \033[1m{:.2f}%\033[0m".format(pct_death_italy), "nos números óbitos devido à Covid-19.\n")
print("================================================================================================================================")
# Out:
# Aumento percentual nos casos de Covid-19 (por milhão): Países no top 5 de 2020 - Comparação entre 24/05/2020 e 24/05/2021 (período de um ano)
# ---------------------------------------------------------------------------------------------------------------------------------------------
# San Marino apresentou um aumento de 765.26%  nos números de casos.
# Catar apresentou um aumento de 493.53% nos números de casos.
# Vaticano apresentou um aumento de 225.00% nos números de casos.
# Andorra apresentou um aumento de 1780.71% nos números de casos.
# Luxemburgo apresentou um aumento de 1742.11% nos números de casos.
#
#
# Aumento percentual no nº de óbitos devido à Covid-19 (por milhão): Países no top 5 de 2020 - Comparação entre 24/05/2020 e 24/05/2021 (período de um ano)
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Percebemos que houve um aumento muito grande nos números dos países que apareciam no top 5 de 24/05/2020 quando comparamos seus números com a mesma data de 2021, ainda que alguns não estejam no top 5 deste ano, excetuando-se Andorra e San Marino.
#
# É interessante notar que todos os países no top 5 de 24/05/2020, exceto o Catar, estão situados no continente europeu. Isso talvez possa ser explicado pela suspensão nas restrições feitas em vários países no continente, no início de maio de 2020, o que levou ao surgimento de focos de infecções por coronavírus (Fonte: [Veja](https://veja.abril.com.br/mundo/na-europa-focos-de-coronavirus-surgem-apos-suspensao-de-restricoes/)). O continente enfrentou uma grave onda de casos nos meses de março e abril de 2020 (Fonte: G1, [aqui](https://g1.globo.com/bemestar/coronavirus/noticia/2020/03/13/europa-e-o-novo-epicentro-da-epidemia-de-coronavirus-diz-oms.ghtml) e [aqui](https://g1.globo.com/bemestar/coronavirus/noticia/2020/04/19/europa-ultrapassa-marca-de-100-mil-mortos-por-covid-19-aponta-universidade.ghtml)), o que também pode explicar os expressivos números vistos.

# %% [markdown]
# ### Panorama de vacinação mundial <a name='vacinacao_mundo'></a>
#
# Dez meses, esse foi o tempo que levou para o desenvolvimento de uma vacina contra a Covid-19 ([Fonte](https://www.bbc.com/portuguese/internacional-55049893)). Esse tempo é considerado um recorde nunca visto na história da humanidade para o desenvolvimento de um imunizante.
#
# Aqui analisaremos o avanço da vacinação mundial, verificando os números totais no panorama da vacinação e os países com os maiores e melhores números. Para traçar um percentual mundial na evolução da vacinação utilizaremos os dados referentes a população mundial projetada para o ano de 2021 disponíveis no site [Population Pyramid](https://www.populationpyramid.net/pt/mundo/2021/). O site disponibiliza um CSV com a quantidade de habitantes divididos por sexo e faixa etária ([Link aqui](https://www.populationpyramid.net/api/pp/900/2021/?csv=true)), que foi copiado e está disponível no meu GitHub ([Aqui](https://raw.githubusercontent.com/LuisCSGuimaraes/AnalisePandemiaCovid19/main/RawData/WORLD-2021.csv))

# %%
#Importando os dados a respeito da população
df_populacao = pd.read_csv("https://raw.githubusercontent.com/LuisCSGuimaraes/AnalisePandemiaCovid19/main/RawData/WORLD-2021.csv")
df_populacao.head()
# Out:
#      Age          M          F
# 0    0-4  349524863  328762461
# 1    5-9  344376197  323101366
# 2  10-14  333944004  312273127
# 3  15-19  318945048  297685601
# 4  20-24  309162637  289633429

# %%
#Somando e criando a variável com o total da população para 2021
populacao2021 = df_populacao.M.sum() + df_populacao.F.sum()

#Criando as variáveis com a quantidade de pessoas que receberam pelo menos uma dose da vacina e que foram completamente vacinadas no mundo
pessoas_vacinadas_mundo = df.people_vaccinated.loc[(df.date == '2021-05-24') & (df.location == 'World')].tolist()[0]
pessoas_completamente_vacinadas_mundo = df.people_fully_vaccinated.loc[(df.date == '2021-05-24') & (df.location == 'World')].tolist()[0]

#Imprimindo informações estatisticas a respeito da vacinação
print("\n       Percentual da população vacinada contra Covid-19 - dados referentes a 24/05/2021")
print("-------------------------------------------------------------------------------------------------\n")
print('Aproximadamente \33[1m{:.2f}%\33[0m'.format((pessoas_vacinadas_mundo / populacao2021)*100), 'da população mundial recebeu ao menos uma dose de vacina contra a Covid-19.')
print('Aproximadamente \33[1m{:.2f}%\33[0m'.format((pessoas_completamente_vacinadas_mundo / populacao2021)*100), 'da população mundial foi completamente vacinada.\n')
print("=================================================================================================")
# Out:
#        Percentual da população vacinada contra Covid-19 - dados referentes a 24/05/2021
# -------------------------------------------------------------------------------------------------
#
# Aproximadamente 9.85% da população mundial recebeu ao menos uma dose de vacina contra a Covid-19.
# Aproximadamente 5.02% da população mundial foi completamente vacinada.
#
# ...

# %%
#Criando um novo dataframe apenas referente a vacinação
df_vacinacao_abs = df.loc[(df.continent.notnull()) & (df.date == '2021-05-24')].sort_values(by='people_vaccinated', ascending=False)[0:5]
df_vacinacao_ph = df.loc[(df.continent.notnull()) & (df.date == '2021-05-24')].sort_values(by='people_vaccinated_per_hundred', ascending=False)[0:5]
df_vacinacao_comp_abs = df.loc[(df.continent.notnull()) & (df.date == '2021-05-24')].sort_values(by='people_fully_vaccinated', ascending=False)[0:5]
df_vacinacao_comp_ph = df.loc[(df.continent.notnull()) & (df.date == '2021-05-24')].sort_values(by='people_fully_vaccinated_per_hundred', ascending=False)[0:5]

#Aplicando o estilo ao gráfico
with plt.rc_context(rc_params_bar):

    #Criando a figura
    fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(16,12))
    
    #Gráfico XIII 
    g1 = sns.barplot(x='location', y='people_vaccinated', ax=ax[0,0], data= df_vacinacao_abs, palette='Greens_r')
    ax[0,0].ticklabel_format(style='plain', axis='y')
    ax[0,0].set_title('Gráfico XIII - Número de pessoas que receberam ao menos uma dose da vacina (números absolutos).')
    ax[0,0].set_ylabel('Pessoas vacinadas')
    ax[0,0].set_xlabel('País')

    for p in g1.patches:
        g1.annotate(format(p.get_height(), ',.0f'),
                        (p.get_x()+ p.get_width() / 2., p.get_height()),
                        ha = 'center', va = 'center',
                        xytext = (0,4),
                        textcoords = 'offset points',
                        size = 10,
                        color = '#404040')

    #Gráfico XIV
    g2 = sns.barplot(x='location', y='people_vaccinated_per_hundred', ax=ax[0,1], data= df_vacinacao_ph, palette='GnBu_r')
    ax[0,1].set_title('Gráfico XIV - Número de pessoas que receberam ao menos uma dose da vacina (por 100 habitantes).')
    ax[0,1].set_ylabel('Pessoas vacinadas (por 100 habitantes)')
    ax[0,1].set(ylim=(0,100))
    ax[0,1].set_xlabel('País')

    for p in g2.patches:
        g2.annotate(format(p.get_height(), ',.0f'),
                        (p.get_x()+p.get_width() /2. , p.get_height()),
                        ha = 'center', va = 'center',
                        xytext = (0,4),
                        textcoords = 'offset points',
                        size = '10',
                        color = '#404040')                                               

    #Gráfico XV
    g3 = sns.barplot(x='location', y='people_fully_vaccinated', ax=ax[1,0], data= df_vacinacao_comp_abs, palette='Greens_r')
    ax[1,0].ticklabel_format(style='plain', axis='y')
    ax[1,0].set_title('Gráfico XV - Número de pessoas completamente vacinadas (números absolutos)')
    ax[1,0].set_ylabel('Pessoas completamente vacinadas')
    ax[1,0].set_xlabel('País')

    for p in g3.patches:
        g3.annotate(format(p.get_height(), ',.0f'),
                        (p.get_x()+p.get_width() /2. , p.get_height()),
                        ha='center', va='center',
                        xytext=(0,4),
                        textcoords = 'offset points',
                        size = '10',
                        color = '#404040')

    #Gráfico XVI
    g4 = sns.barplot(x='location', y='people_fully_vaccinated_per_hundred', ax=ax[1,1], data= df_vacinacao_comp_ph, palette='GnBu_r')
    ax[1,1].set_title('Gráfico XVI - Número de pessoas completamente vacinadas (por 100 habitantes)')
    ax[1,1].set_ylabel('Pessoas completamente vacinadas (por 100 habitantes)')
    ax[1,1].set(ylim=(0,100))
    ax[1,1].set_xlabel('País')

    for p in g4.patches:
        g4.annotate(format(p.get_height(), ',.0f'),
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha = 'center', va ='center',
                        xytext = (0,4),
                        textcoords = 'offset points',
                        size = '10',
                        color = '#404040')

#Exibindo os gráficos
plt.tight_layout()

# %% [markdown]
# Percebemos mais uma vez uma grande diferença ao analisarmos os dados absolutos em comparação aos dados normalizados por população.
#
# Nos gráficos acima temos:
#  * Do lado esquerdo - os números absolutos de pessoas vacinadas com pelo menos uma dose (Gráfico XIII) e de pessoas completamente vacinadas (Gráfico XV).
#  * Do lado direito - os números de pessoas vacinadas com pelo menos uma dose (Gráfico XIV) e de pessoas completamente vacinadas (Gráfico XVI) para cada 100 habitantes.
#
# O único país que aparece no top 5 ao utilizarmos as duas métricas são os Estados Unidos, que consegue aparecer em primeira posição em números absolutos no total de pessoas completamente vacinadas e em quarto lugar nessa mesma análise utilizando os números para 100 habitantes.
#
# Interessante notarmos, também, que a primeira colocação para o número de pessoas com ao menos uma dose por 100 habitantes é a Ilha de Man, uma pequena ilha de dependência da Coroa do Reino Unido e que possui cerca [85 mil Habitantes](https://countrymeters.info/pt/Isle_of_Man).

# %% [markdown]
# ## Panorama brasileiro  <a name='brasil'></a>

# %% [markdown]
# ### Qual a situação da pandemia no Brasil? <a name='situacao_brasil'></a>
#
# Neste segunda parte serão analisados os dados da pandemia referentes ao Brasil de modo que seja possível verificar a evolução dos casos no país em comparação com o restante do mundo, além de uma comparação em relação à vacinação

# %%
#Mudando o estilo do Seaborn
sns.set_theme(style='whitegrid')

# %%
#Definindo os dados que serão utilizados
df_brasil = df.loc[df.location == "Brazil"].copy()

#Criando a figure
figure, ax = plt.subplots(figsize=(15,6), ncols=2)

#Configurando o estilo do seaborn
sns.despine(top=True, right=True)
sns.set_context("paper", rc={"font.size":8,"axes.titlesize":12}) 

#Plotando o Gráfico XVII
sns.lineplot(x='date', y='new_cases_smoothed', ax=ax[0], data=df_brasil, color='purple', linewidth=.9 )
ax[0].set_ylabel("Novos casos suavizados em 7 dias")
ax[0].set_xlabel("Data")
ax[0].set_title("Gráfico XVII - Novos casos de COVID-19 (7 dias) no Brasil")

#Plotando o Gráfico XVIII
sns.lineplot(x='date', y='new_deaths_smoothed', ax=ax[1], data=df_brasil, color='black', linewidth=.9 )
ax[1].set_ylabel("Novas mortes suavizadas em 7 dias")
ax[1].set_xlabel("Data")
ax[1].set_title("Gráfico XVIII - Novas mortes devido à COVID-19 (7 dias) no Brasil")

#Exibindo os gráficos
plt.tight_layout()

# %%
#Passando os valores para listas para serem exibidos
df_stats_obito_brasil = df_brasil[["location","total_deaths"]].sort_values(by="total_deaths", ascending=False).values.tolist()
df_stats_casos_brasil = df_brasil[["location","total_cases"]].sort_values(by="total_cases", ascending=False).values.tolist()
df_stats_obito_million_brasil = df_brasil[["location","total_deaths_per_million"]].sort_values(by="total_deaths_per_million", ascending=False).values.tolist()
df_stats_casos_million_brasil = df_brasil[["location","total_cases_per_million"]].sort_values(by="total_cases_per_million", ascending=False).values.tolist()
populacao_brasil2020 = df_brasil.population.loc[(df.date == '2020-12-31')].values.tolist()
mortalidade_brasil = (df_brasil.total_deaths.max() * 100000/populacao_brasil2020[0])
letalidade_brasil = (df_brasil.total_deaths.max() * 100)/df_brasil.total_cases.max()

#Exibindo os valores armazenados

print("\n---------ESTATÍSTICAS DA COVID-19 NO BRASIL ATÉ O ÚLTIMO DIA ANALISADO - 25/05/2021, COM DADOS DO DIA 24/05/2021----------")
print("--------------------------------------------------------------------------------------------------------------------------\n")
print("* Casos totais de Covid-19 no país: {:,.0f}".format(df_brasil.total_cases.max()))
print("* Quantidade de óbitos devidos à Covid-19: {:,.0f}".format(df_brasil.total_deaths.max()))
print("* O Brasil apresenta, até a data deste estudo, {:,.0f}".format(df_stats_obito_million_brasil[0][1]), "óbitos por milhão de infectados.")
print("* O Brasil apresenta, até a data deste estudo, {:,.0f}".format(df_stats_casos_million_brasil[0][1]), "novos casos de Covid-19 por milhão de habitantes.")
print("* A taxa de letalidade da Covid-19 no país, até a data deste estudo, é de {:.2f}%".format(letalidade_brasil),". Enquanto a taxa de letalidade mundial é de {:.2f}%.".format(letalidade) )
print("* A taxa de mortalidade da Covid-19 no país, considerando sua população em 2020, é de {:.0f}".format(mortalidade_brasil),"a cada 100.000 habitantes.\n  Em comparação, a taxa de mortalidade mundial é de {:.0f}".format(mortalidade),"a cada 100.000 habitantes.\n")
print("==========================================================================================================================")
# Out:
# ---------ESTATÍSTICAS DA COVID-19 NO BRASIL ATÉ O ÚLTIMO DIA ANALISADO - 25/05/2021, COM DADOS DO DIA 24/05/2021----------
# --------------------------------------------------------------------------------------------------------------------------
#
# * Casos totais de Covid-19 no país: 16,120,756
# * Quantidade de óbitos devidos à Covid-19: 449,858
# * O Brasil apresenta, até a data deste estudo, 2,116 óbitos por milhão de infectados.
# * O Brasil apresenta, até a data deste estudo, 75,841 novos casos de Covid-19 por milhão de habitantes.
# * A taxa de letalidade da Covid-19 no país, até a data deste estudo, é de 2.79% . Enquanto a taxa de letalidade mundial é de 2.08%.
# * A taxa de mortalidade da Covid-19 no país, considerando sua população em 2020, é de 212 a cada 100.000 habitantes.
#   Em comparação, a taxa de mortalidade mundial é de 45 a cada 100.000 habitantes.
#
# ...

# %% [markdown]
# Ao analisarmos os gráficos percebemos uma queda nos números entre os meses de julho e novembro de 2020, meses que vieram após a primeira onda da doença e foram marcados com lockdowns e muito medo e desconhecimento por parte da população em relação à doença. Em seguida, de novembro em diante, percebemos o rápido aumento nos números, que pode ser explicado pela segunda onda que atingiu o país e pelo "cansaço" das pessoas em relação ao vírus (Fonte: [G1](https://g1.globo.com/bemestar/coronavirus/noticia/2020/12/29/dezembro-tem-maior-numero-de-mortes-por-covid-19-no-brasil-desde-setembro-indicam-secretarias-de-saude.ghtml)), o que pode ter causado um relaxamento nos cuidados gerais, agravando o quadro de contaminações.
#
# Nas estatísticas gerais, percebemos que o país tem taxas de letalidade e mortalidade maiores que o restante do mundo. Com atenção especial à taxa de mortalidade, sendo mais de 4,5x maior que a taxa mundial.

# %% [markdown]
# ### Comparação entre 24/05/2020 e 24/05/2021  <a name='comparacao_brasil'></a>
#
# De maneira semelhante a análise realizada no panorama mundial, analisaremos os números do total de mortes e do total de casos por milhão de habitantes no período de um ano, entre 24/05/2020 e 24/05/2021, porém comparando os dados do Brasil com os dados do mundo.
#
# Temos apenas que considerar que os números referentes ao mundo podem estar incompletos e não refletir a realidade devido aos problemas já relatados na tópico [Análise inicial](#analise_inicial), no início deste estudo (Dificuldade na coleta de dados, alguns países não disponibilizam dados completos, etc.).

# %%
#Criando um dataframe com os dados de casos por milhão do Brasil e do mundo para 24/05/2020
df_comp_cases_br_2020 = df_brasil.loc[df_brasil.date == '2020-05-24'].sort_values(by='total_cases_per_million', ascending = False)
df_comp_cases_br_2020 = pd.concat([df_comp_cases_br_2020, df.loc[(df.date == '2020-05-24') & (df.location == 'World')].sort_values(by = 'total_cases_per_million', ascending = False)], ignore_index = True)

#Criando um dataframe com os dados de casos por milhão do Brasil e do mundo para 24/05/2021
df_comp_cases_br_2021 = df_brasil.loc[df_brasil.date == '2021-05-24'].sort_values(by='total_cases_per_million', ascending = False)
df_comp_cases_br_2021 = pd.concat([df_comp_cases_br_2021, df.loc[(df.date == '2021-05-24') & (df.location == 'World')].sort_values(by = 'total_cases_per_million', ascending = False)], ignore_index = True)

#Concatenando os dataframes
comparativo_cases_brasil = pd.concat([df_comp_cases_br_2020, df_comp_cases_br_2021], ignore_index=True)

#Criando a coluna Ano para melhor exibição
comparativo_cases_brasil['Ano'] = comparativo_cases_brasil.date.dt.year


#Criando um dataframe com os dados de óbitos por milhão do Brasil e do mundo para 24/05/2020
df_comp_deaths_br_2020 = df_brasil.loc[df_brasil.date == '2020-05-24'].sort_values(by='total_deaths_per_million', ascending = False)
df_comp_deaths_br_2020 = pd.concat([df_comp_deaths_br_2020, df.loc[(df.date == '2020-05-24') & (df.location == 'World')].sort_values(by = 'total_deaths_per_million', ascending = False)], ignore_index = True)

#Criando um dataframe com os dados de óbitos por milhão do Brasil e do mundo para 24/05/2021
df_comp_deaths_br_2021 = df_brasil.loc[df_brasil.date == '2021-05-24'].sort_values(by='total_deaths_per_million', ascending = False)
df_comp_deaths_br_2021 = pd.concat([df_comp_deaths_br_2021, df.loc[(df.date == '2021-05-24') & (df.location == 'World')].sort_values(by = 'total_deaths_per_million', ascending = False)], ignore_index = True)

#Concatenando os dataframes
comparativo_deaths_brasil = pd.concat([df_comp_deaths_br_2020, df_comp_deaths_br_2021], ignore_index=True)

#Criando a coluna Ano para melhor exibição
comparativo_deaths_brasil['Ano'] = comparativo_deaths_brasil.date.dt.year

# %%
#Exibindo o gráfico XIX - comparativo do aumento de casos do Brasil vs o aumento dos casos no mundo - 24/05/2020 e 24/05/2021
ccb = sns.catplot(x='Ano', y='total_cases_per_million', col='location', data=comparativo_cases_brasil, kind='bar',  ci=None, height=6 ,aspect=.9, palette = 'RdPu')
(ccb.set_axis_labels("", "Total de casos (por milhão)")
  .set_titles("{col_name}")) 
ccb.fig.subplots_adjust(top=0.8)
ccb.fig.suptitle('Gráfico XIX - Casos por milhão (Brasil x mundo) - Comparativo 24/05/2020 - 24/05/2021', fontsize=15)  


#Exibindo os números acima de cada barra
ax = ccb.facet_axis(0,0)

for p in ax.patches:
    ax.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')

ax = ccb.facet_axis(0,1)

for p in ax.patches:
    ax.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')


#Exibindo o gráfico XX - comparativo do aumento de óbitos do Brasil vs o aumento dos obitos no mundo - 24/05/2020 e 24/05/2021
cdb = sns.catplot(x='Ano', y='total_deaths_per_million', col='location', data=comparativo_deaths_brasil, kind='bar',  ci=None, height=6,  aspect=.9, palette = 'afmhot_r')
(cdb.set_axis_labels("", "Total de óbitos (por milhão)")
  .set_titles("{col_name}")) 
cdb.fig.subplots_adjust(top=0.8)
cdb.fig.suptitle('Gráfico XX - Óbitos por milhão (Brasil x mundo) - Comparativo 24/05/2020 - 24/05/2021', fontsize=15)  


#Exibindo os números acima de cada barra
ax = cdb.facet_axis(0,0)

for p in ax.patches:
    ax.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')

ax = cdb.facet_axis(0,1)

for p in ax.patches:
    ax.annotate(format(p.get_height(), ',.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 4), 
                   textcoords = 'offset points',
                   size = 10,
                   color = '#404040')

#exibindo os gráficos
plt.show()

# %%
#Variáveis para o cálculo do aumento percetual de casos por milhão no Brasil
cases_br_2020 = comparativo_cases_brasil.total_cases_per_million.loc[(comparativo_cases_brasil.location == 'Brazil') & (comparativo_cases_brasil.date == '2020-05-24')].tolist() 
cases_br_2021 = comparativo_cases_brasil.total_cases_per_million.loc[(comparativo_cases_brasil.location == 'Brazil') & (comparativo_cases_brasil.date == '2021-05-24')].tolist()

#Variáveis para o cálculo do aumento percetual de casos por milhão no mundo
cases_mundo_2020 = comparativo_cases_brasil.total_cases_per_million.loc[(comparativo_cases_brasil.location == 'World') & (comparativo_cases_brasil.date == '2020-05-24')].tolist() 
cases_mundo_2021 = comparativo_cases_brasil.total_cases_per_million.loc[(comparativo_cases_brasil.location == 'World') & (comparativo_cases_brasil.date == '2021-05-24')].tolist()

#Variáveis para o cálculo do aumento percentual de óbitos por milhão no Brasil
deaths_br_2020 = comparativo_deaths_brasil.total_deaths_per_million.loc[(comparativo_deaths_brasil.location == 'Brazil') & (comparativo_deaths_brasil.date == '2020-05-24')].tolist() 
deaths_br_2021 = comparativo_deaths_brasil.total_deaths_per_million.loc[(comparativo_deaths_brasil.location == 'Brazil') & (comparativo_deaths_brasil.date == '2021-05-24')].tolist()

#Variáveis para o cálculo do aumento percentual de óbitos por milhão no mundo
deaths_mundo_2020 = comparativo_deaths_brasil.total_deaths_per_million.loc[(comparativo_deaths_brasil.location == 'World') & (comparativo_deaths_brasil.date == '2020-05-24')].tolist() 
deaths_mundo_2021 = comparativo_deaths_brasil.total_deaths_per_million.loc[(comparativo_deaths_brasil.location == 'World') & (comparativo_deaths_brasil.date == '2021-05-24')].tolist()

#Exibindo as informações do percentual de aumento de casos e óbitos por milhão no Brasil e no mundo
print("\nCOMPARAÇÃO DO AUMENTO PERCENTUAL DE CASOS E DE ÓBITOS DEVIDO À COVID-19 - BRASIL X MUNDO - NO PERÍODO DE 1 ANO (24/05/2020 E 24/05/2021)")
print("----------------------------------------------------------------------------------------------------------------------------------------\n")
print('O número de casos de Covid-19 por milhão de habitantes no Brasil aumentou \033[1m{:,.2f}%\033[0m'.format((cases_br_2021[0] / cases_br_2020[0]) * 100), 'no período analisado.')
print('O número de óbitos por milhão de habitantes no Brasil aumentou \033[1m{:,.2f}%\033[0m'.format((deaths_br_2021[0] / deaths_br_2020[0]) * 100), 'no período analisado.')
print('O número de casos de Covid-19 por milhão de habitantes no mundo aumentou \033[1m{:,.2f}%\033[0m'.format((cases_mundo_2021[0] / cases_mundo_2020[0]) * 100), 'no período analisado.')
print('O número de óbitos por milhão de habitantes no mundo aumentou \033[1m{:,.2f}%\033[0m'.format((deaths_mundo_2021[0] / deaths_mundo_2020[0]) * 100), 'no período analisado.\n')
print('O Brasil registrou, em 24/05/2021, um número de casos por milhão \033[1m{:,.2f}%\033[0m'.format((cases_br_2021[0] / cases_mundo_2021[0] *100)), 'maior do que o número de casos, também por milhão, para o mundo.')
print('O número de óbitos no Brasil, por milhão, em 24/05/2021, foi \033[1m{:,.2f}%\033[0m'.format((deaths_br_2021[0] / deaths_mundo_2021[0] *100)), 'maior do que o registrado no mundo na mesma data.')
print("=========================================================================================================================================")
# Out:
# COMPARAÇÃO DO AUMENTO PERCENTUAL DE CASOS E DE ÓBITOS DEVIDO À COVID-19 - BRASIL X MUNDO - NO PERÍODO DE 1 ANO (24/05/2020 E 24/05/2021)
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# O número de casos de Covid-19 por milhão de habitantes no Brasil aumentou 4,438.40% no período analisado.
# O número de óbitos por milhão de habitantes no Brasil aumentou 1,984.72% no período analisado.
# O número de casos de Covid-19 por milhão de habitantes no mundo aumentou 3,086.09% no período analisado.
# O número de óbitos por milhão de habitantes no mundo aumentou 996.13% no período analisado.
#
# O Brasil registrou, em 24/05/2021, um número de casos por milhão 353.32% maior do que o número de casos, também por milhão, para o mundo.
# O número de óbitos no Brasil, por milhão, em 24/05/2021, foi 475.00% maior do que o registrado no mundo na mesma data.
# ...

# %% [markdown]
# Ainda que os números relacionados ao mundo não sejam completos devido à falta de dados de alguns países, percebemos que o Brasil teve um aumento significativamente maior no número de casos e de óbitos por milhão de habitantes. Entre 24/05/2020 e 24/05/2021 os casos de Covid-19, por milhão, saltaram de aproximadamente 1.709 para 75.841, enquanto os números de óbitos devido a doença foram de aproximadamente 107 para 2116 óbitos por milhão de habitantes no mesmo período.

# %% [markdown]
# ### Panorama de vacinação no Brasil <a name='vacinacao_brasil'></a>
#
# Como último tópico analisaremos o panorama de vacinação no Brasil. Verificaremos qual o atual estado da vacinação da população, a quantidade de pessoas vacinadas com ao menos uma dose, quantas pessoas foram completamente vacinadas no país, a porcentagem total da população que já recebeu o imunizante e a comparação do Brasil com o restante do mundo.
#
# Para calcular a porcentagem da população vacinada irei, novamente, utilizar os dados disponibilizados pelo portal [Population Pyramid](https://www.populationpyramid.net/pt/brasil/2021/) para o ano de 2021, desta vez utilizando somente os dados do Brasil. O csv utilizado também está disponível em meu GitHub, [aqui](https://raw.githubusercontent.com/LuisCSGuimaraes/AnalisePandemiaCovid19/main/RawData/Brazil-2021.csv).

# %%
#Importando os dados a respeito da população do Brasil
df_populacao_br = pd.read_csv('https://raw.githubusercontent.com/LuisCSGuimaraes/AnalisePandemiaCovid19/main/RawData/Brazil-2021.csv')
df_populacao_br.head()
# Out:
#      Age        M        F
# 0    0-4  7357796  7027050
# 1    5-9  7456918  7126488
# 2  10-14  7550011  7244662
# 3  15-19  8110694  7827868
# 4  20-24  8630334  8410568

# %%
#Somando e criando a variável da população do Brasil para 2021
populacao2021br = df_populacao_br.M.sum() + df_populacao_br.F.sum()

#Criando as variáveis com a quantidade de pessoas que receberam pelo menos uma dose da vacina e que foram completamente vacinadas no Brasil
pessoas_vacinadas_br = df_brasil.people_vaccinated.loc[df_brasil.date == '2021-05-24'].tolist()[0]
pessoas_completamente_vacinadas_br= df_brasil.people_fully_vaccinated.loc[df_brasil.date == '2021-05-24'].tolist()[0]

#Imprimindo informações estatisticas a respeito da vacinação
print("\n       Percentual da população vacinada contra Covid-19 - dados referentes a 24/05/2021")
print("-------------------------------------------------------------------------------------------------\n")
print("---Dados para o Brasil:")
print('O Brasil vacinou \33[1m{:,.0f}\33[0m'.format(pessoas_vacinadas_br), 'com ao menos uma dose da vacina.')
print('O Brasil vacinou completamente \33[1m{:,.0f}\33[0m'.format(pessoas_completamente_vacinadas_br), 'pessoas.')
print('Aproximadamente \33[1m{:.2f}%\33[0m'.format((pessoas_vacinadas_br / populacao2021br)*100), 'dos brasileiros recebeu ao menos uma dose de vacina contra a Covid-19.')
print('Aproximadamente \33[1m{:.2f}%\33[0m'.format((pessoas_completamente_vacinadas_br / populacao2021br)*100), 'dos brasileiros foi completamente vacinada.\n')
print("\n---Dados para o mundo:")
print('Aproximadamente \33[1m{:.2f}%\33[0m'.format((pessoas_vacinadas_mundo / populacao2021)*100), 'da população mundial recebeu ao menos uma dose de vacina contra a Covid-19.')
print('Aproximadamente \33[1m{:.2f}%\33[0m'.format((pessoas_completamente_vacinadas_mundo / populacao2021)*100), 'da população mundial foi completamente vacinada.\n')
print("=================================================================================================")
# Out:
#        Percentual da população vacinada contra Covid-19 - dados referentes a 24/05/2021
# -------------------------------------------------------------------------------------------------
#
# ---Dados para o Brasil:
# O Brasil vacinou 39,742,084 com ao menos uma dose da vacina.
# O Brasil vacinou completamente 18,823,574 pessoas.
# Aproximadamente 18.57% dos brasileiros recebeu ao menos uma dose de vacina contra a Covid-19.
# Aproximadamente 8.80% dos brasileiros foi completamente vacinada.
#
#
# ---Dados para o mundo:
# Aproximadamente 9.85% da população mundial recebeu ao menos uma dose de vacina contra a Covid-19.
# Aproximadamente 5.02% da população mundial foi completamente vacinada.
#
# ...

# %% [markdown]
# No quesito vacinação, os números do Brasil são melhores que o restante do mundo. Mais de 39 milhões de brasileiros já tomaram ao menos uma dose da vacina contra a Covid-19 e mais de 18 milhões foram completamente vacinados contra a doença.
#
# O mundo apresenta 9,85% de sua população vacina com ao menos uma dose e 5,02% completamente vacinada, na data de 24/05/2021. Esses números são superiores no Brasil, sendo 18,57% da população total com ao menos uma dose e 8,8% completamente vacinada (utilizando os dados de população disponibilizados pelo portal [Population Pyramid](https://www.populationpyramid.net) para o cálculo).
#
# Veremos uma comparação dos números da vacinação por 100 habitantes entre o Brasil e o mundo na data de 24/05/2021 e em seguida um histórico da evolução desses mesmos números desde o início da vacinação.

# %%
#Criando um novo dataframe para ser utilizao no comparativo de vacinação
df_comp_vacinacao = df_brasil.loc[df_brasil.date == '2021-05-24']
df_comp_vacinacao = pd.concat([df_comp_vacinacao, df.loc[(df.date == '2021-05-24') & (df.location == 'World')]], ignore_index= True)


#Aplicando o estilo ao gráfico
with plt.rc_context(rc_params_bar):

    #Criando a figura
    fig, ax = plt.subplots(nrows = 2, ncols=2, figsize=(18,14))
    
    #Gráfico XXI 
    g1 = sns.barplot(x='location', y='people_vaccinated_per_hundred', ax=ax[0,0], data= df_comp_vacinacao, palette='Blues_r')
    ax[0,0].ticklabel_format(style='plain', axis='y')
    ax[0,0].set_title('Gráfico XXI - Pessoas que receberam ao menos uma dose da vacina - 24/05/2021 - (por 100 habitantes).')
    ax[0,0].set_ylabel('Pessoas vacinadas')
    ax[0,0].set_xlabel('Local')

    for p in g1.patches:
        g1.annotate(format(p.get_height(), ',.0f'),
                        (p.get_x()+ p.get_width() / 2., p.get_height()),
                        ha = 'center', va = 'center',
                        xytext = (0,4),
                        textcoords = 'offset points',
                        size = 10,
                        color = '#404040')

    #Gráfico XXII 
    g2 = sns.barplot(x='location', y='people_fully_vaccinated_per_hundred', ax=ax[0,1], data= df_comp_vacinacao, palette='GnBu_r')
    ax[0,1].ticklabel_format(style='plain', axis='y')
    ax[0,1].set_title('Gráfico XXII - Número de pessoas completamente vacinadas - 24/05/2021 - (por 100 habitantes)).')
    ax[0,1].set_ylabel('Pessoas vacinadas')
    ax[0,1].set_xlabel('Local')

    for p in g2.patches:
        g2.annotate(format(p.get_height(), ',.0f'),
                        (p.get_x()+ p.get_width() / 2., p.get_height()),
                        ha = 'center', va = 'center',
                        xytext = (0,4),
                        textcoords = 'offset points',
                        size = 10,
                        color = '#404040')
    #Gráfico XXIII
    g3 = sns.lineplot(x='date', y='people_vaccinated_per_hundred', ax=ax[1,0], data=df_brasil, color='Green', linewidth=1.2, label='Brasil' )
    g4 = sns.lineplot(x='date', y='people_vaccinated_per_hundred', ax=ax[1,0], data=df.loc[df.location == 'World'], color='Black', linewidth=.9, label = 'Mundo' )
    ax[1,0].set_title('Gráfico XXIII - Evolução da vacinação - ao menos uma dose - Brasil x Mundo (por 100 habitantes)')
    ax[1,0].set_ylabel('Pessoas vacinadas')
    ax[1,0].set_xlabel('Data')

    #Gráfico XXIV
    g5 = sns.lineplot(x='date', y='people_fully_vaccinated_per_hundred', ax=ax[1,1], data=df_brasil, color='Blue', linewidth=1.2, label = 'Brasil' )
    g6 = sns.lineplot(x='date', y='people_fully_vaccinated_per_hundred', ax=ax[1,1], data=df.loc[df.location == 'World'], color='Black', linewidth=.9, label = 'Mundo' )
    ax[1,1].set_title('Gráfico XXIV - Evolução da vacinação - todas as doses - Brasil x Mundo (por 100 habitantes)')
    ax[1,1].set_ylabel('Pessoas vacinadas')
    ax[1,1].set_xlabel('Data')


#Exibindo os gráficos
plt.show()

# %% [markdown]
# Vemos que, apesar de a vacinação ter iniciado depois, o Brasil apresenta números em constante evolução. Na data de 24/05/2021 o país tem uma taxa de 19 pessoas por 100 habitantes vacinados com ao menos uma dose e 9 a cada 100 habitantes completamente vacinados. Apesar de aparentemente baixos, esses números são superiores aos do mundo, que possui 10 pessoas a cada 100 com ao menos uma dose e 5 a cada 100 habitantes completamente vacinados.

# %% [markdown]
# # Considerações finais <a name='consideracoes_finais'></a>

# %% [markdown]
# Através deste estudo conseguimos perceber a rápida propagação que a Covid-19 possui, aumentando os números de novos casos de maneira muito rápida em um período de apenas um ano e ceifando a vida de milhões nesse processo. Países grandes e populosos tem um grande peso na curva e nos números da doença, porém ao utilizarmos os dados normalizados por quantidade populacional conseguimos perceber que os países menores são os mais afetados, possuindo números maiores e mais expressivos em comparação.
#
# Apesar de o desenvolvimento da vacina ter ocorrido muito rapidamente e de forma recorde e uma parcela grande da população já ter sido vacinada, ainda temos um longo caminho até que todos recebam o imunizante e estejam protegidos contra a doença.
#
# Nesse cenário o Brasil apresenta dois extremos: apesar de os números de vacinação estarem maiores e melhores que os números para o restante do mundo, os números de casos e óbitos também estão maiores, apresentando um pico assustador entre os meses de março e abril de 2021.
#
# Fato é que, enquanto a população não está completamente protegida da doença, as medidas simples e eficientes para contenção do vírus devem continuar sendo seguidas de modo a conter o avanço e a disseminação da Covid-19.
